# %%
from sklearn import datasets 
from numpy import random
from sklearn.model_selection import train_test_split

import numpy as np

num_factor = 8

## 更新模型参数
def update(x, mult, v, w, w0, alpha):
    w0 -= alpha * mult
    for i in range(len(x)):
        w[i] -= alpha * (mult * x[i])
        
    for f in range(num_factor):
        for i in range(len(x)):
            grad = s[f] * x[i] - v[i,f] * x[i] * x[i]
            v[i,f] -= alpha * (mult * grad )

## 计算模型预测值
def predict(x, v, w, w0, s, sum_sqr):
    result = np.dot(w, x) + w0 # w*x
        
    # v*x 的 变形
    for f in range(num_factor):
        s[f] = 0
        sum_sqr[f] = 0
        for i in range(len(x)):
            d = v[i,f] * x[i]
            s[f] += d
            sum_sqr[f] += d*d
        result += 0.5 * (s[f] * s[f] - sum_sqr[f])
        
    return result

## 模型训练
def fit(X, y, s, sum_sqr, iter_num = 100, alpha = 0.01):
    num_samples = len(y)
    random.seed(1)
    w0 = random.random(1)
    v = random.random((X.shape[1], num_factor))
    w = random.random(X.shape[1])
    
    for i in range(iter_num):
        for j in range(len(y)):
            x = X[j]
            target = y[j]
            p = predict(x, v, w, w0, s, sum_sqr)
            
            mult = sigmoid(p)-target
            
            update(x, mult, v, w, w0, alpha)
        
    return v, w, w0

## sigmoid 函数
def sigmoid(x):
    return 1.0/(1.0+np.exp(-x))

if __name__=='__main__':
    iris = datasets.load_iris()
    X = iris.data[:100]
    y = iris.target[:100]
    
    train_x, test_x, train_y, test_y = train_test_split(X, y, random_state=0)
    
    s = np.zeros(num_factor)
    sum_sqr = np.zeros(num_factor)
    
    v, w, w0 = fit(train_x, train_y, s, sum_sqr)
    
    print(s)
    print(sum_sqr)
    
    for i in range(len(test_y)):
        predict_value = predict(test_x[i], v, w, w0, s, sum_sqr)
        label = sigmoid(predict_value)
        print(test_y[i], label)
# Out:
# [3.81191456 0.17211336 1.12395572 1.86338571 2.33736091 1.18772958
#  2.39160541 3.37648056]
# [ 7.12102405  8.80618082  7.49272697  2.24127809 30.74340319  2.06512197
#   6.09092346  3.74485244]
# 0 [0.00037493]
# 1 [0.99999981]
# 0 [0.00012513]
# 1 [0.9999998]
# 1 [0.99999617]
# 1 [0.99944236]
# 0 [2.66791258e-06]
# 1 [0.99999825]
# 1 [0.99999982]
# 1 [0.99999591]
# 1 [0.99999744]
# 1 [0.99997509]
# 1 [0.99999997]
# 0 [0.00024311]
# 0 [4.26012896e-05]
# 0 [0.00036004]
# 0 [1.42887941e-05]
# 0 [0.00052281]
# 0 [1.37148689e-07]
# 0 [0.00136353]
# 0 [0.00168659]
# 1 [0.9991695]
# 0 [0.00053858]
# 1 [0.99997983]
# 0 [0.00051107]
